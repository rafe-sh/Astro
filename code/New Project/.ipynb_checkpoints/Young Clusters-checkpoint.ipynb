# %% [markdown]
# # Observational Evidence of Intracluster Dust Evolution in Open Clusters

# %% [markdown]
# ## Imports

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from sklearn.neighbors import NearestNeighbors
import scipy as sp
from scipy.spatial import distance
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_scatter_density 
from matplotlib.colors import LinearSegmentedColormap
from scipy.optimize import curve_fit
from sklearn.mixture import GaussianMixture

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## open clusters dataset

# %%
open_clusters = pd.read_excel('../../data/open clusters table.xlsx')

# %%
oc = open_clusters[['Name', 'logt']].dropna(axis=0).drop(index=0)
oc['logt'] = oc.logt.astype(float)

# %%
oc.describe().transpose()
# Out:
#       count      mean       std  min    25%    50%    75%    max
# logt  911.0  8.079481  0.768238  6.0  7.455  8.155  8.635  10.08

# %%
oc[10**oc['logt'] < 5 * 10**6]
# Out:
#               Name   logt
# 92         ASCC 75  6.650
# 134       ASCC 117  6.670
# 168     Berkeley 7  6.600
# 226       Bochum 2  6.665
# 261  Collinder 232  6.670
# 351        IC 1590  6.540
# 495       NGC 1980  6.670
# 707       NGC 6618  6.000
# 953  vdB-Hagen 121  6.640

# %% [markdown]
# -----

# %% [markdown]
# ## Functions

# %%
def preprocess_cluster(data, g_mean_th=18):
    """
    ------
    parallax > 0 

    phot_g_mean_mag < g_mean_th
    ------
    """
    data = data[data['parallax'] > 0]
    data = data[data['phot_g_mean_mag'] < g_mean_th]
    data['Gmg'] = data['phot_g_mean_mag'] + (5 * np.log10(data['parallax']) - 10)
    data['L'] = 10**(0.4*(4.83 - data['Gmg']))
    print(len(data))
    return data

# %%
def cmd_plot(data, x_axis, y_axis, alpha=0.8, s=5):
    """
    -------
    plot isochron
    -------
    """
    with plt.style.context(['ieee']):
        fig = plt.figure(figsize=(6,6), dpi=100)
        sns.scatterplot(data=data, y=y_axis, x=x_axis, alpha=alpha, s=s)
        plt.gca().invert_yaxis();

# %%
def joint_plot(data):
    plt.figure(dpi=90)
    sns.jointplot(
        data=data,
        x="pmra", y="pmdec",
        kind="kde"
        );

# %%
def fit_curve(data, column, bins = 100):
    
    plt.figure(figsize=(12,3), dpi=120)
    counts, bins, patches = plt.hist(data[column], bins = bins)

    # Define the Gaussian function
    def gaussian(x, amp, mu, sigma):
        return amp * np.exp(-(x - mu)**2 / (2 * sigma**2))
    
    # data
    x_data = bins[:-1]
    y_data = counts
    
    # Fit the Gaussian function to the data
    popt, pcov = curve_fit(gaussian, x_data, y_data)
    
    plt.figure(figsize=(12,3), dpi=120)
    # Plot the original data and the fitted curve
    sns.scatterplot(x_data, y_data, label=column)
    plt.plot(x_data, gaussian(x_data, *popt), color='red', label='Fit')
    plt.legend()
    plt.show()
    
    return popt

# %%
def guassian_filter(data, column, mu, std):    
    up = round(mu + 3 * std, 2)
    low = round(mu - 3 * std, 2)
    
    if up > low:
        print('upper bound:', up) 
        print('lower bound:', low)
        df = data[(data[column] < up) & (data[column] > low)]
    else:
        print('upper bound:', low) 
        print('lower bound:', up)
        df = data[(data[column]< low) & (data[column] > up)]
    
    print('cluster length:', len(df))
    return df

# %%
def luminosity_density(cluster_3d, clusterdf):
    """
    --------
    cluster_3d --> measuring distance in that dataframe
    
    clusterdf --> main dataframe
    -------
    """
    # create a NearestNeighbors object and fit the dataset
    nbrs = NearestNeighbors(n_neighbors=6, metric='minkowski').fit(cluster_3d)

    # find the 5 nearest neighbors for each data point including itself
    distances, indices = nbrs.kneighbors(cluster_3d)

    # find maximum distance among 5 neighbors
    max_distances = np.amax(distances, axis=1)

    # sphere of that max distance
    spheres = (4/3) * np.pi * (max_distances ** 3)

    # sum of luminosities of each 6 nn
    lum_sum = []
    for i in range(len(clusterdf)):
        lum_sum.append(np.sum(clusterdf.iloc[indices[i]]['L']))

    # luminosity density
    lum_dens = lum_sum / spheres

    return lum_dens

# %%
def lum_plot(data):
    """
    --------
    plot for luminosity density profile
    --------
    """
    
    with plt.style.context(['ieee']):
        plt.figure(figsize=(12,6), dpi=200)
        plt.plot(range(len(data)), np.sort(data))
        plt.ylabel('ΔL/ΔV')
        plt.title('luminosity density profile');

# %% [markdown]
# ---------

# %% [markdown]
# ## Young Clusters

# %% [markdown]
# ### NGC 6618

# %% [markdown]
# ```sql
# SELECT gaia_source.source_id, gaia_source.ra ,
# gaia_source.ra_error, gaia_source.dec ,
# gaia_source.dec_error, gaia_source.parallax,
# gaia_source.parallax_error, gaia_source.pmra,
# gaia_source.pmdec, gaia_source.phot_g_mean_mag,
# gaia_source.bp_rp, gaia_source.bp_g,
# gaia_source.g_rp, gaia_source.radial_velocity,
# gaia_source.radial_velocity_error, gaia_source.phot_variable_flag,
# gaia_source.l, gaia_source.b,
# dist.r_med_geo, dist.r_med_photogeo
# FROM gaiadr3.gaia_source
# LEFT JOIN external.gaiaedr3_distance as dist on (gaia_source.source_id = dist.source_id )
# WHERE
# CONTAINS(
# 	POINT('ICRS',gaiadr3.gaia_source.ra,gaiadr3.gaia_source.dec),
# 	CIRCLE(
# 		'ICRS',
# 		COORD1(EPOCH_PROP_POS(275.1958,-16.1717,.6000,1.5100,-1.7400,-44.5770,2000,2016.0)),
# 		COORD2(EPOCH_PROP_POS(275.1958,-16.1717,.6000,1.5100,-1.7400,-44.5770,2000,2016.0)),
# 		0.18333333333333332)
# )=1
#
# ```

# %%
df_NGC_6618 = pd.read_csv('../../data/NGC 6618-result.csv')

# %%
df_NGC_6618 = preprocess_cluster(df_NGC_6618, g_mean_th=18)
# Out:
# 1624

# %%
cmd_plot(df_NGC_6618, 'bp_rp', 'phot_g_mean_mag')

# %%
df_NGC_6618_new = df_NGC_6618.drop(['phot_variable_flag', 'source_id', 'l', 'b', 'dec_error', 'parallax_error', 
                            'bp_g', 'ra_error', 'radial_velocity', 'radial_velocity_error'],
                          axis=1).dropna(axis=0)
len(df_NGC_6618_new)
# Out:
# 1609

# %%
joint_plot(df_NGC_6618_new)

# %%
# Initial Filter on PMRA and PMDEC based on joint plot
df_NGC_6618_new = df_NGC_6618_new[abs(df_NGC_6618_new['pmra']) < 20]
df_NGC_6618_new = df_NGC_6618_new[abs(df_NGC_6618_new['pmdec']) < 20]
len(df_NGC_6618_new)
# Out:
# 1578

# %%
joint_plot(df_NGC_6618_new)

# %%
cmd_plot(df_NGC_6618_new, 'bp_rp', 'phot_g_mean_mag')

# %% [markdown]
# ## Filters

# %% [markdown]
# **NGC 6618:**
#
# Proper motions mas/yr based on [SIMBAD](https://simbad.u-strasbg.fr/simbad/sim-basic?Ident=NGC+6618&submit=SIMBAD+search):
# ```python
#     pmra:   1.510
#     pmdec: -1.740
# ```

# %%
# df_NGC_6618_new = df_NGC_6618_new[abs(df_NGC_6618_new['pmra'])  < 5]
# df_NGC_6618_new = df_NGC_6618_new[abs(df_NGC_6618_new['pmdec']) < 5]
# len(df_NGC_6618_new)

# %%
amp, mu, std = fit_curve(df_NGC_6618_new, 'pmra', bins=125)

# %%
df_NGC_6618_new = guassian_filter(df_NGC_6618_new, 'pmra', mu, std)
# Out:
# upper bound: 4.87
# lower bound: -5.31
# cluster length: 1431

# %%
# df_NGC_6618_new = df_NGC_6618_new[(df_NGC_6618_new['pmdec'] < 0) & (df_NGC_6618_new['pmdec'] > -3)]

# %%
amp, mu, std = fit_curve(df_NGC_6618_new, 'pmdec', bins=100)

# %%
df_NGC_6618_new = guassian_filter(df_NGC_6618_new, 'pmdec', mu, std)
# Out:
# upper bound: 4.49
# lower bound: -8.97
# cluster length: 1336

# %%
amp, mu, std = fit_curve(df_NGC_6618_new, 'parallax', bins=110)

# %%
df_NGC_6618_new = guassian_filter(df_NGC_6618_new, 'parallax', mu, std)
# Out:
# upper bound: 1.2
# lower bound: 0.04
# cluster length: 1260

# %% [markdown]
# ### GMM

# %%
gm = GaussianMixture(n_components=2, random_state=0)

y_pred = gm.fit_predict(df_NGC_6618_new[['pmra', 'pmdec']])
df_NGC_6618_new['cluster'] = y_pred

# %%
sns.jointplot(x='pmra', y='pmdec',data=df_NGC_6618_new, kind='scatter', hue='cluster');

# %%
sns.jointplot(x='pmra', y='pmdec',data=df_NGC_6618_new, kind='kde', hue='cluster');

# %%
amp, mu, std = fit_curve(df_NGC_6618_new[df_NGC_6618_new['cluster'] == 1], 'pmdec', bins=20)

# %% [markdown]
# ---
# ---
# ---

# %%
with plt.style.context(['ieee']):
    fig = plt.figure(figsize=(6,6), dpi=100)
    sns.scatterplot(data=df_NGC_6618_new[df_NGC_6618_new['cluster'] == 1],
                    y='phot_g_mean_mag', x='bp_rp', 
                    hue='cluster', alpha=0.8, s=10, )
    plt.gca().invert_yaxis();

# %%
with plt.style.context(['ieee']):
    fig = plt.figure(figsize=(6,6), dpi=100)
    sns.scatterplot(data=df_NGC_6618_new[df_NGC_6618_new['cluster'] == 1], y='g_rp', x='bp_rp',hue='cluster', alpha=0.8, s=10, )
    plt.gca().invert_yaxis();
plt.plot(np.linspace(0,5, 100), (1.3 * np.linspace(0,2, 100)) + 0.2)
plt.gca().invert_yaxis();

# %%
# Cluster Center based on SIMBAD
SkyCoord(l = 15.0953 , b = -.7454, unit='deg',  frame='galactic').icrs
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (275.19589212, -16.17164067)>

# %%
C = df_NGC_6618_new[df_NGC_6618_new['cluster'] == 1]

plt.figure(figsize=(6, 6), dpi=90)

sns.scatterplot(data = df_NGC_6618_new, x = 'ra', y='dec', alpha=0.8, s=10, hue='cluster')

sns.scatterplot(data = C [(( C['bp_rp'] * 1.2 ) + 0.3) <= C['g_rp']],
                x = 'ra', y = 'dec', color = 'red')

sns.scatterplot(x = [275.19589212], y = [-16.17164067], color = 'orange', label = 'center', alpha=0.6)
# Out:
# <AxesSubplot:xlabel='ra', ylabel='dec'>

# %%
df_NGC_6618_new[((df_NGC_6618_new['bp_rp']*1.2)+0.3 ) < df_NGC_6618_new['g_rp']]
# Out:
#               ra        dec  parallax      pmra     pmdec  phot_g_mean_mag  \
# 825   275.157437 -16.183328  0.301067  0.594847 -1.864466        17.195278
# 1117  275.171338 -16.187248  0.376081  0.186168 -0.425496        17.425497
# 1335  275.203545 -16.198545  0.455314  1.315330 -0.283389        17.203642
# 1398  275.272245 -16.192723  0.018195 -0.102180 -2.235543        17.825590
# 1674  275.147732 -16.191816  0.349778 -0.042450 -1.171734        17.028381
# 2032  275.239625 -16.198654  0.098628  0.578966 -0.961582        17.783100
# 3252  275.141650 -16.202393  0.633336  0.139929 -2.066501        17.046612
# 3506  275.163670 -16.174612  0.739259 -0.404704 -1.647317        17.120586
# 3911  275.211427 -16.151495  0.500586 -0.706512 -1.499193        17.995949
# 4185  275.254450 -16.204216  0.533265 -2.937879 -1.026870        16.800007
# 4274  275.213544 -16.193541  0.489317 -0.671610 -2.339246        17.610987
# 5350  275.194288 -16.241198  0.195918 -0.396268 -0.499340        17.868692
# 5596  275.201168 -16.218201  0.469622  1.528132 -0.600753        17.959332
# 6294  275.196883 -16.169956  0.475755  1.674831 -0.507802        16.416342
# 6357  275.240436 -16.202056  0.521833 -1.041442 -1.951498        17.850286
# 7936  275.128022 -16.195864  0.364983  0.745663 -1.549606        17.603080
#
#          bp_rp      g_rp        r_est       Gmg           L  cluster
# 825   1.287437  2.099644  3026.067702  4.588596    1.248997        0
# 1117  1.302387  2.006235  2655.095856  5.301901    0.647500        0
# 1335  1.002040  1.627633  2172.440137  5.495196    0.541903        1
# 1398  1.187143  1.984312  4622.050743 -0.874604  191.355825        0
# 1674  1.424845  2.112764  2807.969792  4.747345    1.079101        0
# 2032  1.098029  1.860131  4205.520104  2.753109    6.772615        0
# 3252  1.339441  2.082708  1572.257084  6.054783    0.323658        0
# 3506  1.131776  1.835240  1340.098508  6.464569    0.221908        0
# 3911  1.162115  1.915485  2085.385061  6.493344    0.216104        0
# 4185  1.038633  1.667311  1834.260026  5.434723    0.572942        2
# 4274  0.978281  1.821701  2075.644212  6.058936    0.322423        0
# 5350  1.455378  2.209962  3465.386942  4.329068    1.586255        0
# 5596  1.234487  2.158662  2354.137368  6.318076    0.253963        1
# 6294  1.196001  1.976198  2052.140657  4.803259    1.024935        1
# 6357  1.196192  2.041014  2084.178856  6.437943    0.227417        2
# 7936  1.537063  2.277379  2650.058131  5.414446    0.583743        0
