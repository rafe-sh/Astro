# %% [markdown]
# ## Converting Coordinates with Astropy

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datashader as ds
from datashader.mpl_ext import dsshow

# %%
# 4 Points on the Galectic Plane 

x = [0 , 90, 180, 270]
y = 0

# %%
c = SkyCoord(l = x, b = y, unit='deg',  frame='galactic')

# %%
c.icrs
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(266.40498829, -28.93617776), (318.00438151,  48.32963721),
#      ( 86.40498829,  28.93617776), (138.00438151, -48.32963721)]>

# %%
# 2 Points on Up and Below of Galectic Plane

c = SkyCoord(l = 0, b = [90, -90], unit='deg', frame='galactic')

# %%
c.icrs
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(192.85947789,  27.12825241), ( 12.85947789, -27.12825241)]>

# %% [markdown]
# ## Reading csv files

# %%
# SELECT  gaia_source.source_id,gaia_source.ra,gaia_source.dec,gaia_source.parallax,gaia_source.parallax_error,gaia_source.astrometric_n_good_obs_al,gaia_source.astrometric_chi2_al,gaia_source.visibility_periods_used,gaia_source.phot_g_mean_flux_over_error,gaia_source.phot_g_mean_mag,gaia_source.phot_bp_mean_flux_over_error,gaia_source.phot_bp_mean_mag,gaia_source.phot_rp_mean_flux_over_error,gaia_source.phot_rp_mean_mag,gaia_source.phot_bp_rp_excess_factor,gaia_source.bp_rp,gaia_source.l,gaia_source.b
# FROM gaiadr2.gaia_source 
# WHERE 
# CONTAINS(
# 	POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),
# 	CIRCLE('ICRS',266.40498829,-28.93617776,1)
# )=1

# %%
df0_0 = pd.read_csv('./data/0_0 - 1 deg-result.csv')
df90_0 = pd.read_csv('./data/90_0 - 1 deg - 10000-result.csv')
df180_0 = pd.read_csv('./data/180_0 - 1 deg - 10000-result.csv')
df270_0 = pd.read_csv('./data/270_0 - 1 deg - 10000-result.csv')
df0_90 = pd.read_csv('./data/0_90 - 1 deg - 10000-result.csv')
df0_180 = pd.read_csv('./data/0_-90 - 1 deg - 10000-result.csv')

# %%
df0_0.sample(5)
# Out:
#                 source_id          ra  ra_error        dec  dec_error  \
# 4212  4057240963557380224  267.352559  0.849560 -29.222082   0.772445
# 4812  4057240684374200704  267.415436  0.049455 -29.213368   0.043565
# 9322  4057237939905471872  267.289267  5.421933 -29.329652   4.994390
# 606   4057237832519204736  267.241256  0.442016 -29.360503   0.378928
# 3930  4057239314292898560  267.309262  0.130418 -29.269008   0.111795
#
#       parallax  parallax_error  phot_g_mean_mag     bp_rp
# 4212  1.305989        0.790892        20.331050  1.367071
# 4812  0.596384        0.049731        15.589433  1.850925
# 9322       NaN             NaN        20.818918       NaN
# 606   0.060196        0.401995        19.154100  3.518980
# 3930  0.439483        0.131053        17.638120  1.562849

# %%
df0_0[~(df0_0['parallax'].isnull()) & ~(df0_0['bp_rp'].isnull())]
# Out:
#                 source_id          ra  ra_error        dec  dec_error  \
# 2     4057239967148228480  267.335779  0.081787 -29.277096   0.068339
# 4     4057237287064910720  267.409604  0.359259 -29.269156   0.322588
# 5     4057238485350454272  267.330635  0.161787 -29.291368   0.135342
# 7     4057236668613282560  267.388654  0.077250 -29.319147   0.064263
# 8     4057238210481316608  267.354180  1.067236 -29.309192   0.875958
# ...                   ...         ...       ...        ...        ...
# 9986  4057233129531794048  267.369836  0.376195 -29.466947   0.313888
# 9987  4057237179690585856  267.471491  0.586118 -29.249365   0.507088
# 9988  4057240207643029376  267.354899  0.618412 -29.239203   0.542624
# 9992  4057241650775227392  267.356826  0.094745 -29.187926   0.085543
# 9996  4057239692249766656  267.364256  0.283256 -29.310364   0.241332
#
#       parallax  parallax_error  phot_g_mean_mag     bp_rp
# 2     0.475668        0.081907        16.661715  1.450008
# 4     0.320221        0.311875        18.577099  1.922123
# 5     0.025440        0.152023        17.801010  2.261810
# 7     0.615354        0.077477        16.568285  1.427678
# 8    -0.595517        0.974607        20.083559  3.009369
# ...        ...             ...              ...       ...
# 9986  0.008762        0.422920        19.387852  1.851990
# 9987 -0.092619        0.785475        19.879953  1.492605
# 9988 -0.202794        0.365911        19.020271  2.516245
# 9992  0.424937        0.107795        17.276592  1.754047
# 9996  0.890798        0.237082        18.515303  1.437483
#
# [4962 rows x 9 columns]

# %% [markdown]
# ### DATA with `r_est` at center
#
#
# query:
# ```
# SELECT source_id, r_est, r_lo, r_hi, gaia_source.source_id,gaia_source.ra,gaia_source.dec,gaia_source.parallax,gaia_source.parallax_error,gaia_source.astrometric_n_good_obs_al,gaia_source.astrometric_chi2_al,gaia_source.visibility_periods_used,gaia_source.phot_g_mean_flux_over_error,gaia_source.phot_g_mean_mag,gaia_source.phot_bp_mean_flux_over_error,gaia_source.phot_bp_mean_mag,gaia_source.phot_rp_mean_flux_over_error,gaia_source.phot_rp_mean_mag,gaia_source.phot_bp_rp_excess_factor,gaia_source.bp_rp,gaia_source.l,gaia_source.b
# FROM external.gaiadr2_geometric_distance
# JOIN gaiadr2.gaia_source USING (source_id)
# WHERE CONTAINS(
# 	POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),
#  	CIRCLE('ICRS',266.40498829,-28.93617776,1)
# )=1
# ```

# %%
full_df = pd.read_csv('./data/full data 0_0.csv')

# %%
full_df.describe().transpose()
# Out:
#                                  count          mean           std  \
# source_id                     287201.0  4.057877e+18  1.218236e+15
# r_est                         287201.0  3.404074e+03  1.623435e+03
# r_lo                          287201.0  1.787546e+03  8.046925e+02
# r_hi                          287201.0  6.580786e+03  3.009504e+03
# ra                            287201.0  2.665588e+02  6.323661e-01
# dec                           287201.0 -2.890813e+01  4.863533e-01
# parallax                      287201.0  4.844414e-01  9.461790e-01
# parallax_error                287201.0  4.960419e-01  4.344289e-01
# astrometric_n_good_obs_al     287201.0  1.199195e+02  2.316286e+01
# astrometric_chi2_al           287201.0  2.022827e+02  8.922931e+02
# visibility_periods_used       287201.0  9.169091e+00  1.180573e+00
# phot_g_mean_flux_over_error   287201.0  4.879091e+02  5.930700e+02
# phot_g_mean_mag               287201.0  1.848232e+01  1.614170e+00
# phot_bp_mean_flux_over_error  264375.0  5.187882e+01  1.856000e+03
# phot_bp_mean_mag              264375.0  1.935024e+01  1.657775e+00
# phot_rp_mean_flux_over_error  264665.0  1.139425e+02  4.854174e+02
# phot_rp_mean_mag              264665.0  1.714931e+01  1.463172e+00
# phot_bp_rp_excess_factor      264314.0  1.771876e+00  6.092459e-01
# bp_rp                         264314.0  2.202241e+00  7.007127e-01
# l                             287201.0  1.484390e+02  1.768236e+02
# b                             287201.0 -1.006155e-01  5.818424e-01
#
#                                        min           25%           50%  \
# source_id                     4.056820e+18  4.057230e+18  4.057400e+18
# r_est                         1.301665e+01  1.932577e+03  3.655324e+03
# r_lo                          0.000000e+00  1.211347e+03  1.753638e+03
# r_hi                          1.325552e+01  3.864592e+03  7.709393e+03
# ra                            2.652624e+02  2.660340e+02  2.666642e+02
# dec                          -2.993595e+01 -2.929762e+01 -2.890345e+01
# parallax                     -3.061900e+01  1.666822e-01  4.722105e-01
# parallax_error                2.228644e-02  1.712861e-01  3.637433e-01
# astrometric_n_good_obs_al     4.100000e+01  1.050000e+02  1.220000e+02
# astrometric_chi2_al           1.953511e+01  1.164525e+02  1.422127e+02
# visibility_periods_used       6.000000e+00  8.000000e+00  9.000000e+00
# phot_g_mean_flux_over_error   9.185807e+00  1.474332e+02  2.764843e+02
# phot_g_mean_mag               6.979837e+00  1.762502e+01  1.880092e+01
# phot_bp_mean_flux_over_error  3.937756e-02  5.861346e+00  1.281267e+01
# phot_bp_mean_mag              8.125414e+00  1.850806e+01  1.976796e+01
# phot_rp_mean_flux_over_error  7.459375e-02  2.393456e+01  4.817631e+01
# phot_rp_mean_mag              5.677005e+00  1.639860e+01  1.742152e+01
# phot_bp_rp_excess_factor      8.423731e-01  1.387956e+00  1.531855e+00
# bp_rp                        -7.632847e-01  1.780062e+00  2.050166e+00
# l                             7.820000e-06  3.109309e-01  7.196844e-01
# b                            -9.998093e-01 -5.905096e-01 -2.345194e-01
#
#                                        75%           max
# source_id                     4.057600e+18  4.060700e+18
# r_est                         4.698513e+03  1.858595e+04
# r_lo                          2.265535e+03  1.411534e+04
# r_hi                          8.994113e+03  2.436147e+04
# ra                            2.671052e+02  2.675475e+02
# dec                          -2.849189e+01 -2.793646e+01
# parallax                      8.036359e-01  7.684470e+01
# parallax_error                6.914827e-01  3.586241e+00
# astrometric_n_good_obs_al     1.370000e+02  1.890000e+02
# astrometric_chi2_al           1.742719e+02  1.648777e+05
# visibility_periods_used       1.000000e+01  1.100000e+01
# phot_g_mean_flux_over_error   5.847894e+02  8.041238e+03
# phot_g_mean_mag               1.972716e+01  2.099986e+01
# phot_bp_mean_flux_over_error  3.969085e+01  9.503997e+05
# phot_bp_mean_mag              2.055205e+01  2.451811e+01
# phot_rp_mean_flux_over_error  1.129558e+02  1.337710e+05
# phot_rp_mean_mag              1.821434e+01  2.038617e+01
# phot_bp_rp_excess_factor      1.895514e+00  4.999540e+00
# bp_rp                         2.445725e+00  7.662457e+00
# l                             3.596143e+02  3.600000e+02
# b                             3.809556e-01  9.998805e-01

# %%
full_df.sample(4)
# Out:
#            source_id        r_est         r_lo          r_hi          ra  \
# 36194   4.057290e+18  5592.536820  2857.970108  10004.830500  267.216265
# 272067  4.060580e+18  2188.696796  2057.579170   2337.288737  265.665006
# 202517  4.057680e+18  6518.327833  3767.483728  10873.356680  266.986964
# 92543   4.057140e+18  5483.941607  2802.025491   9871.910028  265.370055
#
#               dec  parallax  parallax_error  astrometric_n_good_obs_al  \
# 36194  -29.073784 -1.908061        0.969705                        125
# 272067 -28.214911  0.429758        0.028396                        140
# 202517 -28.132663 -0.565471        0.354500                        150
# 92543  -29.059422 -0.566419        0.620932                        106
#
#         astrometric_chi2_al  ...  phot_g_mean_flux_over_error  \
# 36194             165.21822  ...                    121.30990
# 272067             86.16341  ...                   3365.85470
# 202517            221.75336  ...                    319.20575
# 92543             108.14543  ...                    150.58298
#
#         phot_g_mean_mag  phot_bp_mean_flux_over_error  phot_bp_mean_mag  \
# 36194         20.304787                           NaN               NaN
# 272067        13.966297                    413.355800         14.452325
# 202517        18.945420                     11.248607         20.374937
# 92543         19.750063                      4.991234         20.752272
#
#         phot_rp_mean_flux_over_error  phot_rp_mean_mag  \
# 36194                            NaN               NaN
# 272067                    226.629210         13.272523
# 202517                     50.657010         17.817783
# 92543                      13.846369         18.585596
#
#         phot_bp_rp_excess_factor     bp_rp           l         b
# 36194                        NaN       NaN    0.249911 -0.678158
# 272067                  1.275703  1.179802    0.274173  0.931316
# 202517                  1.400100  2.557154    0.952168 -0.020059
# 92543                   1.536401  2.166676  359.420047  0.705861
#
# [4 rows x 21 columns]

# %%
full_df = full_df[~(full_df['parallax'].isnull()) & ~(full_df['bp_rp'].isnull())]

# %%
# POSITIVE PARALLAX FOR LOG

full_df = full_df[full_df['parallax'] > 0]
full_df['mg'] = full_df['phot_g_mean_mag'] + (5 * np.log10(full_df['parallax']) -10)

# %%
def using_datashader(ax, x, y):

    dsartist = dsshow(
        full_df[['bp_rp', 'mg']],
        ds.Point("bp_rp", "mg"),
        ds.count(),
#         vmin=0,
#         vmax=100,
        norm="linear",
        aspect="auto",
        ax=ax,
        cmap='hot',
        y_range=[-10,20]
    )

    plt.colorbar(dsartist)


fig, ax = plt.subplots(figsize=(10,7))

using_datashader(ax, x, y)

ax.set_title('Without Filters')
ax.set_xlabel('$ G _{bp} - G _{rp} $')
ax.set_ylabel('$ M_{G} $')

plt.tight_layout()
plt.show()

# %%
full_df = full_df[(full_df['phot_g_mean_flux_over_error'] > 50) & (full_df['phot_rp_mean_flux_over_error']>20) & (full_df['phot_bp_mean_flux_over_error']>20)]

# %%
full_df = full_df[full_df['phot_bp_rp_excess_factor'] < (1.3 + 0.06 * ( full_df['phot_bp_mean_mag'] - full_df['phot_rp_mean_mag'])**2)]

# %%
full_df = full_df[full_df['phot_bp_rp_excess_factor'] > (1.0 + 0.015 * ( full_df['phot_bp_mean_mag'] - full_df['phot_rp_mean_mag'])**2)]

# %%
full_df = full_df[full_df['visibility_periods_used'] > 8]

# %%
full_df['MAX'] = np.exp(-0.4 * (full_df['phot_g_mean_mag']-19.5))

# %%
df['MAX'] = df['MAX'].apply(lambda x: 1 if(x<1) else x)

# %%
full_df = full_df[(full_df['astrometric_chi2_al'] / (full_df['astrometric_n_good_obs_al']-5)) < 1.44 * full_df["MAX"]]

# %%
full_df.describe().transpose()
# Out:
#                                 count          mean           std  \
# source_id                     80605.0  4.057617e+18  9.623760e+14
# r_est                         80605.0  2.234358e+03  1.141698e+03
# r_lo                          80605.0  1.617540e+03  6.492318e+02
# r_hi                          80605.0  3.578137e+03  2.378349e+03
# ra                            80605.0  2.666154e+02  5.645512e-01
# dec                           80605.0 -2.897810e+01  4.798912e-01
# parallax                      80605.0  6.025120e-01  4.951990e-01
# parallax_error                80605.0  1.271183e-01  7.075690e-02
# astrometric_n_good_obs_al     80605.0  1.359461e+02  1.763844e+01
# astrometric_chi2_al           80605.0  1.627194e+02  1.161431e+02
# visibility_periods_used       80605.0  1.007760e+01  7.394202e-01
# phot_g_mean_flux_over_error   80605.0  1.096160e+03  7.876961e+02
# phot_g_mean_mag               80605.0  1.670007e+01  1.426094e+00
# phot_bp_mean_flux_over_error  80605.0  1.215312e+02  1.426679e+02
# phot_bp_mean_mag              80605.0  1.761713e+01  1.510131e+00
# phot_rp_mean_flux_over_error  80605.0  2.538192e+02  2.476756e+02
# phot_rp_mean_mag              80605.0  1.573011e+01  1.367011e+00
# phot_bp_rp_excess_factor      80605.0  1.378201e+00  8.746883e-02
# bp_rp                         80605.0  1.887026e+00  4.553018e-01
# l                             80605.0  1.611466e+02  1.786214e+02
# b                             80605.0 -1.794517e-01  5.099750e-01
# mg                            80605.0  5.204884e+00  1.778440e+00
# MAX                           80605.0  3.791325e+00  3.980822e+00
#
#                                        min           25%           50%  \
# source_id                     4.056820e+18  4.057210e+18  4.057300e+18
# r_est                         3.654322e+01  1.436755e+03  1.982730e+03
# r_lo                          3.645945e+01  1.160900e+03  1.528061e+03
# r_hi                          3.662737e+01  1.771578e+03  2.775347e+03
# ra                            2.652652e+02  2.662051e+02  2.667035e+02
# dec                          -2.993595e+01 -2.935298e+01 -2.901493e+01
# parallax                      1.930000e-04  3.756830e-01  5.170781e-01
# parallax_error                2.228644e-02  7.189816e-02  1.141696e-01
# astrometric_n_good_obs_al     7.500000e+01  1.230000e+02  1.370000e+02
# astrometric_chi2_al           2.624874e+01  1.221179e+02  1.454602e+02
# visibility_periods_used       9.000000e+00  1.000000e+01  1.000000e+01
# phot_g_mean_flux_over_error   5.718172e+01  5.874171e+02  8.563218e+02
# phot_g_mean_mag               6.979837e+00  1.596953e+01  1.703245e+01
# phot_bp_mean_flux_over_error  2.000011e+01  3.524726e+01  6.411295e+01
# phot_bp_mean_mag              8.125414e+00  1.682543e+01  1.796783e+01
# phot_rp_mean_flux_over_error  2.008345e+01  9.476074e+01  1.642797e+02
# phot_rp_mean_mag              5.677005e+00  1.503851e+01  1.604331e+01
# phot_bp_rp_excess_factor      1.157198e+00  1.322948e+00  1.365692e+00
# bp_rp                        -7.509995e-02  1.631707e+00  1.848200e+00
# l                             2.860000e-05  3.265363e-01  7.978176e-01
# b                            -9.996193e-01 -6.003969e-01 -2.752693e-01
# mg                           -1.244446e+01  4.193529e+00  5.343176e+00
# MAX                           8.822654e-01  2.021247e+00  2.683222e+00
#
#                                        75%           max
# source_id                     4.057540e+18  4.060700e+18
# r_est                         2.764927e+03  9.758141e+03
# r_lo                          1.976211e+03  7.151443e+03
# r_hi                          5.010786e+03  1.375444e+04
# ra                            2.670752e+02  2.675469e+02
# dec                          -2.859765e+01 -2.793646e+01
# parallax                      7.069881e-01  2.733614e+01
# parallax_error                1.679513e-01  9.093267e-01
# astrometric_n_good_obs_al     1.490000e+02  1.890000e+02
# astrometric_chi2_al           1.724297e+02  5.415918e+03
# visibility_periods_used       1.100000e+01  1.100000e+01
# phot_g_mean_flux_over_error   1.280470e+03  8.041238e+03
# phot_g_mean_mag               1.774071e+01  1.981316e+01
# phot_bp_mean_flux_over_error  1.449193e+02  5.934270e+03
# phot_bp_mean_mag              1.872438e+01  2.164701e+01
# phot_rp_mean_flux_over_error  3.253748e+02  1.885183e+04
# phot_rp_mean_mag              1.672124e+01  1.872146e+01
# phot_bp_rp_excess_factor      1.419013e+00  2.263013e+00
# bp_rp                         2.077770e+00  5.887404e+00
# l                             3.596296e+02  3.600000e+02
# b                             2.167141e-01  9.998805e-01
# mg                            6.395358e+00  1.307018e+01
# MAX                           4.104924e+00  1.496150e+02

# %%
def using_datashader(ax, x, y):

    dsartist = dsshow(
        full_df[['bp_rp', 'mg']],
        ds.Point("bp_rp", "mg"),
        ds.count(),
#         vmin=0,
#         vmax=100,
        norm="linear",
        aspect="auto",
        ax=ax,
        cmap='hot',
        y_range=[-10,20]
    )

    plt.colorbar(dsartist)


fig, ax = plt.subplots(figsize=(10,7))

using_datashader(ax, x, y)

ax.set_title('Filters Enabled')
ax.set_xlabel('$ G _{bp} - G _{rp} $')
ax.set_ylabel('$ M_{G} $')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Extinction

# %%
####
